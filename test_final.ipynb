# %%
# !pip install --upgrade pip -q
# !pip install -qU "transformers>=4.40.0" peft datasets scikit-learn seaborn matplotlib pandas tqdm bitsandbytes accelerate
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 19.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 116.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.1/13.1 MB 145.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.1/76.1 MB 119.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 47.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 150.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 173.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 43.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 31.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 131.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 142.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 66.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 126.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 168.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18/18 [bitsandbytes]
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.2.3 which is incompatible.
# gcsfs 2025.3.2 requires fsspec==2025.3.2, but you have fsspec 2025.3.0 which is incompatible.

# %%
# !pip install -qU --prefer-binary "bitsandbytes>=0.43.1" accelerate

# %%
import os, gc, torch, json, math, random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm
from huggingface_hub import login
from transformers import AutoTokenizer, AutoModelForCausalLM
from peft import PeftModel
from datasets import load_dataset
from sklearn.metrics import (
    classification_report,
    confusion_matrix,
    accuracy_score,
    f1_score,
)
from transformers import BitsAndBytesConfig

login(token="YOUR_HF_TOKEN_HERE")

sns.set(style="whitegrid")
plt.rcParams["figure.dpi"] = 110

def make_prompt(text: str) -> str:
    return (
        "Instruction: What is the sentiment of this news? "
        "Please choose an answer from {negative/neutral/positive}\n"
        f"Input: {text}\n"
        "Answer:"
    )

# %%
dataset = load_dataset("takala/financial_phrasebank", "sentences_allagree")
data = dataset["train"]
sentences = data["sentence"]

label_names = data.features["label"].names
label2id = {name: idx for idx, name in enumerate(label_names)}
id2label = {v: k for k, v in label2id.items()}
y_true = [label2id[label_names[lbl]] for lbl in data["label"]]
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# README.md:   0%|          | 0.00/8.88k [00:00<?, ?B/s]
# financial_phrasebank.py:   0%|          | 0.00/6.04k [00:00<?, ?B/s]
# The repository for takala/financial_phrasebank contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at https://hf.co/datasets/takala/financial_phrasebank.
# You can avoid this prompt in future by passing the argument `trust_remote_code=True`.
#
# Do you wish to run the custom code? [y/N] y
# FinancialPhraseBank-v1.0.zip:   0%|          | 0.00/682k [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/2264 [00:00<?, ? examples/s]

# %%
MODELS = [

    dict(
        pretty="Mistral‑7B‑Base",
        base="unsloth/mistral-7b-v0.2",
        peft=None,
    ),

    dict(
        pretty="Finistral‑7B‑LoRA",
        base="mistralai/Mistral-7B-v0.1",
        peft="Ayansk11/Finistral-7B_lora",
    ),

    dict(
        pretty="fingpt-mt_llama2-7b_lora",
        base="meta-llama/Llama-2-7b-hf",
        peft="FinGPT/fingpt-mt_llama2-7b_lora",
    ),

]

# %%
import re

_SENT_RE = re.compile(r"\b(negative|neutral|positive|neg|neu|pos)\b", re.I)
_map3 = {"neg": 0, "neu": 1, "pos": 2}

def extract_sentiment(text: str) -> str:
    """
    Return 'neg', 'neu', or 'pos' from a model answer string.
    If nothing is found, return 'neu' (neutral).
    """
    t = text.lower()
    if "answer:" in t:
        after = t.split("answer:", 1)[1]
        m = _SENT_RE.search(after)
        if m:
            return m.group(1)[:3]
    m = _SENT_RE.search(t)
    return m.group(1)[:3] if m else "neu"

# %%
def evaluate_model(base_model: str, peft_model: str | None, batch_size: int = 8):
    """Run the exact classification loop you wrote and return metrics dict."""
    # Load tokenizer
    tokenizer = AutoTokenizer.from_pretrained(base_model, use_auth_token=True)
    tokenizer.pad_token = tokenizer.eos_token

    quant_cfg = BitsAndBytesConfig(
        load_in_8bit=True,
        bnb_8bit_compute_dtype=torch.float16,
        bnb_8bit_use_double_quant=True,
        bnb_8bit_quant_type="nf4",
    )

    model = AutoModelForCausalLM.from_pretrained(
        base_model,
        device_map="auto",
        quantization_config=quant_cfg,
        trust_remote_code=True,
        token=True,
        torch_dtype=torch.float16,
    )


    if peft_model:
        model = PeftModel.from_pretrained(model, peft_model)
    model.eval()

    y_pred = []
    for start in tqdm(
        range(0, len(sentences), batch_size),
        desc=f"Running {peft_model or base_model}",
    ):
        batch = sentences[start : start + batch_size]
        prompts = [make_prompt(t) for t in batch]
        tokens = tokenizer(
            prompts, return_tensors="pt", padding=True, max_length=512
        ).to(model.device)

        with torch.no_grad():
            outputs = model.generate(**tokens, max_length=512)



        decoded = tokenizer.batch_decode(outputs, skip_special_tokens=True)
        for out in decoded:
            tag = extract_sentiment(out)
            y_pred.append(_map3[tag])



    acc = accuracy_score(y_true, y_pred)
    f1 = f1_score(y_true, y_pred, average="weighted")
    cls_report = classification_report(
        y_true,
        y_pred,
        target_names=["negative", "neutral", "positive"],
        output_dict=True,
        zero_division=0,
    )
    conf_mat = confusion_matrix(y_true, y_pred)

    del model, tokenizer, tokens, outputs
    torch.cuda.empty_cache()
    gc.collect()

    return {
        "accuracy": acc,
        "weighted_f1": f1,
        "report": cls_report,
        "cm": conf_mat,
    }

# %%
results = {}
for cfg in MODELS:
    print(f"\n💫 Evaluating {cfg['pretty']}...")
    metrics = evaluate_model(cfg["base"], cfg["peft"])
    results[cfg["pretty"]] = metrics
# Out:
# 💫 Evaluating Mistral‑7B‑Base...
# /usr/local/lib/python3.11/dist-packages/transformers/models/auto/tokenization_auto.py:898: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers. Please use `token` instead.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/989 [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# tokenizer.model:   0%|          | 0.00/493k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.80M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/438 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/713 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/23.9k [00:00<?, ?B/s]
# Fetching 3 files:   0%|          | 0/3 [00:00<?, ?it/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# model-00002-of-00003.safetensors:   0%|          | 0.00/5.00G [00:00<?, ?B/s]
# model-00001-of-00003.safetensors:   0%|          | 0.00/4.94G [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# model-00003-of-00003.safetensors:   0%|          | 0.00/4.54G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/155 [00:00<?, ?B/s]
# Running unsloth/mistral-7b-v0.2:   0%|          | 0/283 [00:00<?, ?it/s]/usr/local/lib/python3.11/dist-packages/transformers/tokenization_utils_base.py:2718: UserWarning: `max_length` is ignored when `padding`=`True` and there is no truncation strategy. To pad to max length, use `padding='max_length'`.
#   warnings.warn(
# Running unsloth/mistral-7b-v0.2: 100%|██████████| 283/283 [5:31:11<00:00, 70.22s/it]
# 💫 Evaluating Finistral‑7B‑LoRA...
# /usr/local/lib/python3.11/dist-packages/transformers/models/auto/tokenization_auto.py:898: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers. Please use `token` instead.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/996 [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/493k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.80M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/414 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/571 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/25.1k [00:00<?, ?B/s]
# Fetching 2 files:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/4.54G [00:00<?, ?B/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/9.94G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# adapter_config.json:   0%|          | 0.00/677 [00:00<?, ?B/s]
# adapter_model.safetensors:   0%|          | 0.00/83.9M [00:00<?, ?B/s]
# Running Ayansk11/Finistral-7B_lora:   0%|          | 0/283 [00:00<?, ?it/s]/usr/local/lib/python3.11/dist-packages/transformers/tokenization_utils_base.py:2718: UserWarning: `max_length` is ignored when `padding`=`True` and there is no truncation strategy. To pad to max length, use `padding='max_length'`.
#   warnings.warn(
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:   0%|          | 1/283 [00:00<02:42,  1.74it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:   1%|          | 2/283 [00:01<02:40,  1.75it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:   1%|          | 3/283 [00:01<02:36,  1.79it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:   1%|▏         | 4/283 [00:02<02:33,  1.82it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:   2%|▏         | 5/283 [00:02<02:32,  1.82it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:   2%|▏         | 6/283 [00:03<02:31,  1.82it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:   2%|▏         | 7/283 [00:03<02:29,  1.84it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:   3%|▎         | 8/283 [00:04<02:26,  1.88it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:   3%|▎         | 9/283 [00:04<02:26,  1.87it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:   4%|▎         | 10/283 [00:05<02:25,  1.88it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:   4%|▍         | 11/283 [00:05<02:23,  1.90it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:   4%|▍         | 12/283 [00:06<02:21,  1.92it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:   5%|▍         | 13/283 [00:06<02:20,  1.93it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:   5%|▍         | 14/283 [00:07<02:20,  1.92it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:   5%|▌         | 15/283 [00:08<02:22,  1.88it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:   6%|▌         | 16/283 [00:08<02:23,  1.87it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:   6%|▌         | 17/283 [00:09<02:21,  1.88it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:   6%|▋         | 18/283 [00:09<02:21,  1.87it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:   7%|▋         | 19/283 [00:10<02:21,  1.86it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:   7%|▋         | 20/283 [00:10<02:20,  1.87it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:   7%|▋         | 21/283 [00:11<02:16,  1.92it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:   8%|▊         | 22/283 [00:11<02:17,  1.90it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:   8%|▊         | 23/283 [00:12<02:15,  1.92it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:   8%|▊         | 24/283 [00:12<02:15,  1.91it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:   9%|▉         | 25/283 [00:13<02:15,  1.90it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:   9%|▉         | 26/283 [00:13<02:16,  1.89it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  10%|▉         | 27/283 [00:14<02:15,  1.89it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  10%|▉         | 28/283 [00:14<02:17,  1.86it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  10%|█         | 29/283 [00:15<02:15,  1.88it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  11%|█         | 30/283 [00:16<02:15,  1.86it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  11%|█         | 31/283 [00:16<02:13,  1.89it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  11%|█▏        | 32/283 [00:17<02:11,  1.91it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  12%|█▏        | 33/283 [00:17<02:11,  1.90it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  12%|█▏        | 34/283 [00:18<02:10,  1.91it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  12%|█▏        | 35/283 [00:18<02:12,  1.87it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  13%|█▎        | 36/283 [00:19<02:11,  1.87it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  13%|█▎        | 37/283 [00:19<02:10,  1.89it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  13%|█▎        | 38/283 [00:20<02:10,  1.88it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  14%|█▍        | 39/283 [00:20<02:11,  1.86it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  14%|█▍        | 40/283 [00:21<02:11,  1.85it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  14%|█▍        | 41/283 [00:21<02:10,  1.85it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  15%|█▍        | 42/283 [00:22<02:12,  1.82it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  15%|█▌        | 43/283 [00:23<02:13,  1.80it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  16%|█▌        | 44/283 [00:23<02:13,  1.80it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  16%|█▌        | 45/283 [00:24<02:12,  1.80it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  16%|█▋        | 46/283 [00:24<02:10,  1.81it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  17%|█▋        | 47/283 [00:25<02:10,  1.80it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  17%|█▋        | 48/283 [00:25<02:08,  1.83it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  17%|█▋        | 49/283 [00:26<02:06,  1.86it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  18%|█▊        | 50/283 [00:26<02:05,  1.85it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  18%|█▊        | 51/283 [00:27<02:04,  1.86it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  18%|█▊        | 52/283 [00:27<02:03,  1.86it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  19%|█▊        | 53/283 [00:28<02:02,  1.88it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  19%|█▉        | 54/283 [00:28<02:02,  1.87it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  19%|█▉        | 55/283 [00:29<02:03,  1.85it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  20%|█▉        | 56/283 [00:30<02:01,  1.87it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  20%|██        | 57/283 [00:30<02:01,  1.85it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  20%|██        | 58/283 [00:31<02:00,  1.87it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  21%|██        | 59/283 [00:31<01:58,  1.89it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  21%|██        | 60/283 [00:32<01:58,  1.89it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  22%|██▏       | 61/283 [00:32<01:59,  1.87it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  22%|██▏       | 62/283 [00:33<01:58,  1.87it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  22%|██▏       | 63/283 [00:33<01:57,  1.88it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  23%|██▎       | 64/283 [00:34<01:55,  1.89it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  23%|██▎       | 65/283 [00:34<01:54,  1.91it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  23%|██▎       | 66/283 [00:35<01:54,  1.89it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  24%|██▎       | 67/283 [00:35<01:53,  1.90it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  24%|██▍       | 68/283 [00:36<01:51,  1.92it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  24%|██▍       | 69/283 [00:36<01:50,  1.94it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  25%|██▍       | 70/283 [00:37<01:51,  1.91it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  25%|██▌       | 71/283 [00:37<01:49,  1.93it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  25%|██▌       | 72/283 [00:38<01:52,  1.87it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  26%|██▌       | 73/283 [00:39<01:51,  1.88it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  26%|██▌       | 74/283 [00:39<01:51,  1.87it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  27%|██▋       | 75/283 [00:40<01:49,  1.89it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  27%|██▋       | 76/283 [00:40<01:49,  1.89it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  27%|██▋       | 77/283 [00:41<01:48,  1.90it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  28%|██▊       | 78/283 [00:41<01:47,  1.90it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  28%|██▊       | 79/283 [00:42<01:48,  1.88it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  28%|██▊       | 80/283 [00:42<01:47,  1.89it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  29%|██▊       | 81/283 [00:43<01:46,  1.90it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  29%|██▉       | 82/283 [00:43<01:44,  1.92it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  29%|██▉       | 83/283 [00:44<01:45,  1.89it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  30%|██▉       | 84/283 [00:44<01:44,  1.91it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  30%|███       | 85/283 [00:45<01:43,  1.91it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  30%|███       | 86/283 [00:45<01:43,  1.91it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  31%|███       | 87/283 [00:46<01:43,  1.89it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  31%|███       | 88/283 [00:46<01:41,  1.93it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  31%|███▏      | 89/283 [00:47<01:40,  1.93it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  32%|███▏      | 90/283 [00:47<01:39,  1.94it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  32%|███▏      | 91/283 [00:48<01:40,  1.91it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  33%|███▎      | 92/283 [00:48<01:40,  1.90it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  33%|███▎      | 93/283 [00:49<01:40,  1.90it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  33%|███▎      | 94/283 [00:50<01:39,  1.90it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  34%|███▎      | 95/283 [00:50<01:38,  1.90it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  34%|███▍      | 96/283 [00:51<01:45,  1.78it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  34%|███▍      | 97/283 [00:51<01:43,  1.79it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  35%|███▍      | 98/283 [00:52<01:41,  1.82it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  35%|███▍      | 99/283 [00:52<01:40,  1.84it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  35%|███▌      | 100/283 [00:53<01:40,  1.81it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  36%|███▌      | 101/283 [00:53<01:39,  1.82it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  36%|███▌      | 102/283 [00:54<01:37,  1.85it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  36%|███▋      | 103/283 [00:54<01:37,  1.84it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  37%|███▋      | 104/283 [00:55<01:37,  1.84it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  37%|███▋      | 105/283 [00:56<01:35,  1.86it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  37%|███▋      | 106/283 [00:56<01:33,  1.89it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  38%|███▊      | 107/283 [00:57<01:32,  1.89it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  38%|███▊      | 108/283 [00:57<01:33,  1.86it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  39%|███▊      | 109/283 [00:58<01:34,  1.84it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  39%|███▉      | 110/283 [00:58<01:33,  1.84it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  39%|███▉      | 111/283 [00:59<01:32,  1.87it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  40%|███▉      | 112/283 [00:59<01:30,  1.88it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  40%|███▉      | 113/283 [01:00<01:29,  1.90it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  40%|████      | 114/283 [01:00<01:30,  1.88it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  41%|████      | 115/283 [01:01<01:31,  1.83it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  41%|████      | 116/283 [01:02<01:32,  1.80it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  41%|████▏     | 117/283 [01:02<01:29,  1.85it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  42%|████▏     | 118/283 [01:03<01:28,  1.87it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  42%|████▏     | 119/283 [01:03<01:27,  1.87it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  42%|████▏     | 120/283 [01:04<01:24,  1.92it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  43%|████▎     | 121/283 [01:04<01:24,  1.93it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  43%|████▎     | 122/283 [01:05<01:23,  1.93it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  43%|████▎     | 123/283 [01:05<01:23,  1.91it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  44%|████▍     | 124/283 [01:06<01:22,  1.92it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  44%|████▍     | 125/283 [01:06<01:25,  1.85it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  45%|████▍     | 126/283 [01:07<01:25,  1.83it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  45%|████▍     | 127/283 [01:07<01:26,  1.80it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  45%|████▌     | 128/283 [01:08<01:25,  1.81it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  46%|████▌     | 129/283 [01:08<01:24,  1.83it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  46%|████▌     | 130/283 [01:09<01:22,  1.85it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  46%|████▋     | 131/283 [01:09<01:20,  1.89it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  47%|████▋     | 132/283 [01:10<01:18,  1.92it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  47%|████▋     | 133/283 [01:10<01:17,  1.94it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  47%|████▋     | 134/283 [01:11<01:16,  1.95it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  48%|████▊     | 135/283 [01:11<01:15,  1.96it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  48%|████▊     | 136/283 [01:12<01:15,  1.94it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  48%|████▊     | 137/283 [01:13<01:14,  1.95it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  49%|████▉     | 138/283 [01:13<01:13,  1.96it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  49%|████▉     | 139/283 [01:14<01:14,  1.94it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  49%|████▉     | 140/283 [01:14<01:13,  1.94it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  50%|████▉     | 141/283 [01:15<01:12,  1.95it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  50%|█████     | 142/283 [01:15<01:14,  1.89it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  51%|█████     | 143/283 [01:16<01:16,  1.84it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  51%|█████     | 144/283 [01:16<01:16,  1.83it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  51%|█████     | 145/283 [01:17<01:14,  1.84it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  52%|█████▏    | 146/283 [01:17<01:13,  1.86it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  52%|█████▏    | 147/283 [01:18<01:12,  1.88it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  52%|█████▏    | 148/283 [01:18<01:10,  1.90it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  53%|█████▎    | 149/283 [01:19<01:10,  1.90it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  53%|█████▎    | 150/283 [01:19<01:10,  1.89it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  53%|█████▎    | 151/283 [01:20<01:10,  1.86it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  54%|█████▎    | 152/283 [01:21<01:10,  1.87it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  54%|█████▍    | 153/283 [01:21<01:08,  1.89it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  54%|█████▍    | 154/283 [01:22<01:07,  1.90it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  55%|█████▍    | 155/283 [01:22<01:08,  1.87it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  55%|█████▌    | 156/283 [01:23<01:07,  1.87it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  55%|█████▌    | 157/283 [01:23<01:06,  1.89it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  56%|█████▌    | 158/283 [01:24<01:04,  1.93it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  56%|█████▌    | 159/283 [01:24<01:05,  1.89it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  57%|█████▋    | 160/283 [01:25<01:03,  1.92it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  57%|█████▋    | 161/283 [01:25<01:03,  1.92it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  57%|█████▋    | 162/283 [01:26<01:03,  1.91it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  58%|█████▊    | 163/283 [01:26<01:02,  1.91it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  58%|█████▊    | 164/283 [01:27<01:01,  1.93it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  58%|█████▊    | 165/283 [01:27<01:00,  1.95it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  59%|█████▊    | 166/283 [01:28<00:59,  1.96it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  59%|█████▉    | 167/283 [01:28<01:00,  1.92it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  59%|█████▉    | 168/283 [01:29<01:00,  1.90it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  60%|█████▉    | 169/283 [01:29<01:02,  1.82it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  60%|██████    | 170/283 [01:30<01:02,  1.81it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  60%|██████    | 171/283 [01:31<01:01,  1.81it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  61%|██████    | 172/283 [01:31<00:59,  1.85it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  61%|██████    | 173/283 [01:32<00:58,  1.87it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  61%|██████▏   | 174/283 [01:32<00:57,  1.90it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  62%|██████▏   | 175/283 [01:33<00:56,  1.91it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  62%|██████▏   | 176/283 [01:33<00:55,  1.91it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  63%|██████▎   | 177/283 [01:34<00:55,  1.91it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  63%|██████▎   | 178/283 [01:34<00:54,  1.93it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  63%|██████▎   | 179/283 [01:35<00:53,  1.94it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  64%|██████▎   | 180/283 [01:35<00:52,  1.95it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  64%|██████▍   | 181/283 [01:36<00:51,  1.97it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  64%|██████▍   | 182/283 [01:36<00:51,  1.96it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  65%|██████▍   | 183/283 [01:37<00:50,  1.97it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  65%|██████▌   | 184/283 [01:37<00:51,  1.94it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  65%|██████▌   | 185/283 [01:38<00:50,  1.96it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  66%|██████▌   | 186/283 [01:38<00:49,  1.94it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  66%|██████▌   | 187/283 [01:39<00:49,  1.94it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  66%|██████▋   | 188/283 [01:39<00:49,  1.94it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  67%|██████▋   | 189/283 [01:40<00:48,  1.93it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  67%|██████▋   | 190/283 [01:40<00:48,  1.93it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  67%|██████▋   | 191/283 [01:41<00:47,  1.96it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  68%|██████▊   | 192/283 [01:41<00:45,  1.99it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  68%|██████▊   | 193/283 [01:42<00:45,  1.98it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  69%|██████▊   | 194/283 [01:42<00:45,  1.97it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  69%|██████▉   | 195/283 [01:43<00:45,  1.96it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  69%|██████▉   | 196/283 [01:43<00:44,  1.95it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  70%|██████▉   | 197/283 [01:44<00:45,  1.91it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  70%|██████▉   | 198/283 [01:44<00:44,  1.91it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  70%|███████   | 199/283 [01:45<00:44,  1.88it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  71%|███████   | 200/283 [01:46<00:43,  1.90it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  71%|███████   | 201/283 [01:46<00:42,  1.91it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  71%|███████▏  | 202/283 [01:47<00:42,  1.90it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  72%|███████▏  | 203/283 [01:47<00:41,  1.93it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  72%|███████▏  | 204/283 [01:48<00:41,  1.88it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  72%|███████▏  | 205/283 [01:48<00:41,  1.89it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  73%|███████▎  | 206/283 [01:49<00:40,  1.90it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  73%|███████▎  | 207/283 [01:49<00:40,  1.90it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  73%|███████▎  | 208/283 [01:50<00:39,  1.88it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  74%|███████▍  | 209/283 [01:50<00:39,  1.86it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  74%|███████▍  | 210/283 [01:51<00:39,  1.86it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  75%|███████▍  | 211/283 [01:51<00:38,  1.89it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  75%|███████▍  | 212/283 [01:52<00:37,  1.90it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  75%|███████▌  | 213/283 [01:52<00:36,  1.91it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  76%|███████▌  | 214/283 [01:53<00:35,  1.92it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  76%|███████▌  | 215/283 [01:53<00:35,  1.92it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  76%|███████▋  | 216/283 [01:54<00:34,  1.93it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  77%|███████▋  | 217/283 [01:54<00:34,  1.92it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  77%|███████▋  | 218/283 [01:55<00:33,  1.92it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  77%|███████▋  | 219/283 [01:56<00:33,  1.93it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  78%|███████▊  | 220/283 [01:56<00:32,  1.94it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  78%|███████▊  | 221/283 [01:57<00:31,  1.94it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  78%|███████▊  | 222/283 [01:57<00:31,  1.91it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  79%|███████▉  | 223/283 [01:58<00:31,  1.91it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  79%|███████▉  | 224/283 [01:58<00:31,  1.89it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  80%|███████▉  | 225/283 [01:59<00:30,  1.88it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  80%|███████▉  | 226/283 [01:59<00:29,  1.90it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  80%|████████  | 227/283 [02:00<00:29,  1.90it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  81%|████████  | 228/283 [02:00<00:28,  1.91it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  81%|████████  | 229/283 [02:01<00:27,  1.93it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  81%|████████▏ | 230/283 [02:01<00:27,  1.93it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  82%|████████▏ | 231/283 [02:02<00:26,  1.95it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  82%|████████▏ | 232/283 [02:02<00:26,  1.92it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  82%|████████▏ | 233/283 [02:03<00:26,  1.91it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  83%|████████▎ | 234/283 [02:03<00:25,  1.91it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  83%|████████▎ | 235/283 [02:04<00:25,  1.90it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  83%|████████▎ | 236/283 [02:04<00:24,  1.90it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  84%|████████▎ | 237/283 [02:05<00:24,  1.89it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  84%|████████▍ | 238/283 [02:05<00:23,  1.88it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  84%|████████▍ | 239/283 [02:06<00:23,  1.85it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  85%|████████▍ | 240/283 [02:07<00:23,  1.87it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  85%|████████▌ | 241/283 [02:07<00:22,  1.84it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  86%|████████▌ | 242/283 [02:08<00:21,  1.87it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  86%|████████▌ | 243/283 [02:08<00:21,  1.88it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  86%|████████▌ | 244/283 [02:09<00:20,  1.89it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  87%|████████▋ | 245/283 [02:09<00:20,  1.89it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  87%|████████▋ | 246/283 [02:10<00:19,  1.89it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  87%|████████▋ | 247/283 [02:10<00:18,  1.91it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  88%|████████▊ | 248/283 [02:11<00:18,  1.93it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  88%|████████▊ | 249/283 [02:11<00:17,  1.95it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  88%|████████▊ | 250/283 [02:12<00:16,  1.96it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  89%|████████▊ | 251/283 [02:12<00:16,  1.92it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  89%|████████▉ | 252/283 [02:13<00:16,  1.90it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  89%|████████▉ | 253/283 [02:13<00:15,  1.91it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  90%|████████▉ | 254/283 [02:14<00:15,  1.89it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  90%|█████████ | 255/283 [02:14<00:14,  1.91it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  90%|█████████ | 256/283 [02:15<00:14,  1.90it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  91%|█████████ | 257/283 [02:15<00:13,  1.89it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  91%|█████████ | 258/283 [02:16<00:13,  1.90it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  92%|█████████▏| 259/283 [02:17<00:12,  1.90it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  92%|█████████▏| 260/283 [02:17<00:12,  1.88it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  92%|█████████▏| 261/283 [02:18<00:11,  1.88it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  93%|█████████▎| 262/283 [02:18<00:11,  1.89it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  93%|█████████▎| 263/283 [02:19<00:10,  1.88it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  93%|█████████▎| 264/283 [02:19<00:10,  1.87it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  94%|█████████▎| 265/283 [02:20<00:09,  1.84it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  94%|█████████▍| 266/283 [02:20<00:09,  1.85it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  94%|█████████▍| 267/283 [02:21<00:08,  1.84it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  95%|█████████▍| 268/283 [02:21<00:08,  1.83it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  95%|█████████▌| 269/283 [02:22<00:07,  1.83it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  95%|█████████▌| 270/283 [02:23<00:07,  1.84it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  96%|█████████▌| 271/283 [02:23<00:06,  1.85it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  96%|█████████▌| 272/283 [02:24<00:05,  1.87it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  96%|█████████▋| 273/283 [02:24<00:05,  1.87it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  97%|█████████▋| 274/283 [02:25<00:04,  1.87it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  97%|█████████▋| 275/283 [02:25<00:04,  1.89it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  98%|█████████▊| 276/283 [02:26<00:03,  1.90it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  98%|█████████▊| 277/283 [02:26<00:03,  1.92it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  98%|█████████▊| 278/283 [02:27<00:02,  1.92it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  99%|█████████▊| 279/283 [02:27<00:02,  1.91it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  99%|█████████▉| 280/283 [02:28<00:01,  1.91it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora:  99%|█████████▉| 281/283 [02:28<00:01,  1.87it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora: 100%|█████████▉| 282/283 [02:29<00:00,  1.85it/s]Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Running Ayansk11/Finistral-7B_lora: 100%|██████████| 283/283 [02:29<00:00,  1.89it/s]
# /usr/local/lib/python3.11/dist-packages/transformers/models/auto/tokenization_auto.py:898: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers. Please use `token` instead.
#   warnings.warn(
# 💫 Evaluating fingpt-mt_llama2-7b_lora...
# tokenizer_config.json:   0%|          | 0.00/776 [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.84M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/414 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/609 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/26.8k [00:00<?, ?B/s]
# Fetching 2 files:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/3.50G [00:00<?, ?B/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/9.98G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/188 [00:00<?, ?B/s]
# adapter_config.json:   0%|          | 0.00/460 [00:00<?, ?B/s]
# adapter_model.bin:   0%|          | 0.00/12.6M [00:00<?, ?B/s]
# Running FinGPT/fingpt-mt_llama2-7b_lora:   0%|          | 0/283 [00:00<?, ?it/s]/usr/local/lib/python3.11/dist-packages/transformers/tokenization_utils_base.py:2718: UserWarning: `max_length` is ignored when `padding`=`True` and there is no truncation strategy. To pad to max length, use `padding='max_length'`.
#   warnings.warn(
# Running FinGPT/fingpt-mt_llama2-7b_lora: 100%|██████████| 283/283 [01:31<00:00,  3.08it/s]

# %%
summary_df = pd.DataFrame.from_dict(
    {
        mname: {"Accuracy": m["accuracy"], "Weighted F1": m["weighted_f1"]}
        for mname, m in results.items()
    },
    orient="index",
).round(4).sort_values("Weighted F1", ascending=False)

print("\n=== Overall comparison ===")
display(summary_df)

ax = summary_df.plot(kind="bar", figsize=(8, 5))
plt.title("Model comparison on Financial PhraseBank (sentences_allagree)")
plt.ylabel("Score")
plt.ylim(0, 1)
plt.xticks(rotation=15, ha="right")
plt.tight_layout()
plt.show()
# Out:
# === Overall comparison ===
#                           Accuracy  Weighted F1
# Finistral‑7B‑LoRA           0.9956       0.9956
# Mistral‑7B‑Base             0.4125       0.2967
# fingpt-mt_llama2-7b_lora    0.1564       0.0789

# %%
chosen = "Finistral‑7B‑LoRA"
pd.DataFrame(results[chosen]["report"]).transpose()
sns.heatmap(
    results[chosen]["cm"],
    annot=True,
    fmt="d",
    cmap="Blues",
    xticklabels=label_names,
    yticklabels=label_names,
).set(
    title=f"Confusion matrix – {chosen}",
    xlabel="Predicted",
    ylabel="True",
)
plt.show()
